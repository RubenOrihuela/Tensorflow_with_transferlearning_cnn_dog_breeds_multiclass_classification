# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf

import pathlib

import matplotlib.pyplot as plt

from tensorflow.keras import layers

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization

# %%
ls

# %%
#paths
global_path = os.path.join('')
images_dir = os.path.join(global_path, 'Images')
images_dir = pathlib.Path(images_dir)

# %%
image_count = len(list(images_dir.glob('*/*.jpg')))
print(image_count)

# %%
German_shepherd = list(images_dir.glob('German_shepherd/*'))
PIL.Image.open(str(German_shepherd[0]))

# %%
batch_size = 64
img_height = 227
img_width = 227

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="training",
  seed = 10,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 724 files belonging to 4 classes.
# Using 580 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="validation",
  seed=10,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 724 files belonging to 4 classes.
# Using 144 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['German_shepherd', 'Maltese_dog', 'Saint_Bernard', 'golden_retriever']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    # 1st conv
  tf.keras.layers.Conv2D(96, (11,11),strides=(4,4), activation='relu', input_shape=(227, 227, 3)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2,2)),
    # 2nd conv
  tf.keras.layers.Conv2D(256, (11,11),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
     # 3rd conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 4th conv
  tf.keras.layers.Conv2D(384, (3,3),strides=(1,1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
    # 5th Conv
  tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), activation='relu',padding="same"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, strides=(2, 2)),
  # To Flatten layer
  tf.keras.layers.Flatten(),
  # To FC layer 1
  tf.keras.layers.Dense(4096, activation='relu'),
    # add dropout 0.5 ==> tf.keras.layers.Dropout(0.5),
  #To FC layer 2
  tf.keras.layers.Dense(4096, activation='relu'),
    # add dropout 0.5 ==> tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(len(class_names), activation='softmax')
])

# %%
# Specifying the optimizer, Loss function for optimization & Metrics to be displayed
model.compile(optimizer='Adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# Summarizing the model architecture and printing it out
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 227, 227, 3)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 55, 55, 96)        34944
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 55, 55, 96)        384
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 27, 27, 256)       2973952
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 27, 27, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 27, 27, 384)       885120
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 27, 27, 384)       1536
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 27, 27, 384)       1327488
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 27, 27, 384)       1536
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 27, 27, 256)       884992
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 27, 27, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 43264)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              177213440
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 16388
# =================================================================
# Total params: 200,123,140
# Trainable params: 200,120,388
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
# Training the Model
history = model.fit(
      train_ds,
      validation_data=val_ds,
      epochs=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 188s 19s/step - loss: 1.3693 - accuracy: 0.3397 - val_loss: 1.3858 - val_accuracy: 0.2292
# Epoch 2/5
# 10/10 [==============================] - 182s 18s/step - loss: 1.2118 - accuracy: 0.5052 - val_loss: 1.3852 - val_accuracy: 0.2292
# Epoch 3/5
# 10/10 [==============================] - 154s 15s/step - loss: 1.1177 - accuracy: 0.6241 - val_loss: 1.3832 - val_accuracy: 0.2292
# Epoch 4/5
# 10/10 [==============================] - 153s 15s/step - loss: 1.0224 - accuracy: 0.7431 - val_loss: 1.3821 - val_accuracy: 0.2917
# Epoch 5/5
# 10/10 [==============================] - 149s 15s/step - loss: 0.8977 - accuracy: 0.8690 - val_loss: 1.3813 - val_accuracy: 0.3472
